# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Howard Wang (b08902047@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2023-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
# Download dataset
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
# !unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'/kaggle/input/ml2023spring-hw11-test/real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'/kaggle/input/ml2023spring-hw11-test/real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'/kaggle/input/ml2023spring-hw11-test/real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 

from rich.progress import Progress, TextColumn, BarColumn, TimeElapsedColumn, TimeRemainingColumn, track
import time


source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('/kaggle/input/ml2023spring-hw11-test/real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('/kaggle/input/ml2023spring-hw11-test/real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True, num_workers=4)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True, num_workers=4)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False, num_workers=4)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.downsample = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        residual = self.downsample(residual)
        out += residual
        out = self.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block):
        super(ResNet, self).__init__()
        layers = [2, 1, 1, 1]
        self.in_channels = 64
        self.conv = nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)
        self.layer1 = self.make_layer(block, 64, layers[0])
        self.layer2 = self.make_layer(block, 128, layers[1], 2)
        self.layer3 = self.make_layer(block, 256, layers[2], 2)
        self.layer4 = self.make_layer(block, 512, layers[3], 2)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))

    def make_layer(self, block, out_channels, blocks, stride=1):
        strides = [stride] + [1] * (blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # x: (batch_size, 3, 32, 32)
        out = self.conv(x)
        # out: (batch_size, 64, 32, 32) assuming the conv layer is a 3x3 convolution that pads the input so the height and width don't change, and has 64 output channels
        out = self.bn(out)
        # out: (batch_size, 64, 32, 32) batch normalization doesn't change the shape
        out = self.relu(out)
        # out: (batch_size, 64, 32, 32) ReLU doesn't change the shape
        out = self.layer1(out)
        # out: (batch_size, 64, 32, 32) assuming layer1 doesn't change the number of channels or the height and width
        out = self.layer2(out)
        # out: (batch_size, 128, 16, 16) assuming layer2 doubles the number of channels and halves the height and width
        out = self.layer3(out)
        # out: (batch_size, 256, 8, 8) assuming layer3 doubles the number of channels and halves the height and width
        out = self.layer4(out)
        # out: (batch_size, 512, 4, 4) assuming layer4 doubles the number of channels and halves the height and width
        out = self.avg_pool(out)
        # out: (batch_size, 512, 1, 1) assuming avg_pool is an adaptive pool that reduces the height and width to 1
        out = out.view(out.size(0), -1)
        # out: (batch_size, 512) the view operation flattens the other dimensions
        return out

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.resnet = ResNet(ResidualBlock)
        
    def forward(self, x):
        x = self.conv(x).squeeze()
#         x = self.resnet(x)
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )
#         self.layer = nn.Sequential(
#             nn.Linear(512, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),

#             nn.Linear(256, 128),
#             nn.BatchNorm1d(128),
#             nn.ReLU(),

#             nn.Linear(128, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),

#             nn.Linear(64, 32),
#             nn.BatchNorm1d(32),
#             nn.ReLU(),

#             nn.Linear(32, 1),
#             )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters(), lr=1e-3)
optimizer_C = optim.Adam(label_predictor.parameters(), lr=1e-3)
optimizer_D = optim.Adam(domain_classifier.parameters(), lr=1e-3)

scheduler_F = optim.lr_scheduler.ReduceLROnPlateau(optimizer_F, 'min', factor=0.9, patience=50, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=1e-5, eps=1e-8)
scheduler_C = optim.lr_scheduler.ReduceLROnPlateau(optimizer_C, 'min', factor=0.9, patience=50, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=1e-5, eps=1e-8)
scheduler_D = optim.lr_scheduler.ReduceLROnPlateau(optimizer_D, 'max', factor=0.9, patience=50, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=1e-5, eps=1e-8)

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0
#     batch_tqdm = progress.add_task(description=f"batch_progress", total=len(source_dataloader))

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss+= loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss+= loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
#         progress.advance(batch_tqdm, advance=1)

#     progress.remove_task(batch_tqdm)
    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

num_epochs = 2000
# train 200 epochs
marked_epoch = [10, 200, 500, 999, 1500, 1999]
# with Progress(TextColumn("[progress.description]{task.description}"),
#               BarColumn(),
#               TextColumn("[progress.percentage]{task.percentage:>3.0f}%"),
#               TimeRemainingColumn(),
#               TimeElapsedColumn()) as progress:
#     epoch_tqdm = progress.add_task(description="epoch progress", total=num_epochs)
for epoch in range(num_epochs):
#     lamb = np.log(1.02 + 1.7*epoch/num_epochs)
    lamb = (2 / (1 + np.exp(-10*(epoch/num_epochs)))) - 1
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=2*lamb)
    
    scheduler_D.step(train_D_loss)
    scheduler_F.step(train_F_loss)
    scheduler_C.step(train_acc)
#         progress.advance(epoch_tqdm, advance=1)
#         if epoch == 10:
#           torch.save(feature_extractor.state_dict(), f'extractor_model_early.bin')
#           torch.save(label_predictor.state_dict(), f'predictor_model_early.bin')
#         elif epoch == 100:
#           torch.save(feature_extractor.state_dict(), f'extractor_model_mid.bin')
#           torch.save(label_predictor.state_dict(), f'predictor_model_mid.bin')
    if epoch in marked_epoch:
        torch.save(feature_extractor.state_dict(), f'extractor_model_{epoch}.bin')
        torch.save(label_predictor.state_dict(), f'predictor_model_{epoch}.bin')

#         torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
#         torch.save(label_predictor.state_dict(), f'predictor_model.bin')
    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}, lambda {:6.4f}'.format(epoch + 1, train_D_loss, train_F_loss, train_acc, lamb))
    print('epoch {:>3d}: lr_D:{:.5f}, lr_F:{:.5f}, lr_C:{:.5f}'.\
          format(epoch + 1, optimizer_D.state_dict()['param_groups'][0]['lr'], optimizer_F.state_dict()['param_groups'][0]['lr'], optimizer_C.state_dict()['param_groups'][0]['lr']))
torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
torch.save(label_predictor.state_dict(), f'predictor_model.bin')
# Out:
# epoch   1: train D loss: 0.1425, train F loss: 1.9401, acc 0.2794, lambda 0.0000
# epoch   1: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   2: train D loss: 0.1461, train F loss: 1.6237, acc 0.4182, lambda 0.0025
# epoch   2: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   3: train D loss: 0.2411, train F loss: 1.4894, acc 0.4744, lambda 0.0050
# epoch   3: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   4: train D loss: 0.2603, train F loss: 1.3898, acc 0.5086, lambda 0.0075
# epoch   4: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   5: train D loss: 0.2748, train F loss: 1.3225, acc 0.5320, lambda 0.0100
# epoch   5: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   6: train D loss: 0.3093, train F loss: 1.3001, acc 0.5432, lambda 0.0125
# epoch   6: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   7: train D loss: 0.2966, train F loss: 1.2486, acc 0.5580, lambda 0.0150
# epoch   7: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   8: train D loss: 0.3143, train F loss: 1.2077, acc 0.5802, lambda 0.0175
# epoch   8: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch   9: train D loss: 0.3546, train F loss: 1.1783, acc 0.5862, lambda 0.0200
# epoch   9: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  10: train D loss: 0.3410, train F loss: 1.1308, acc 0.6032, lambda 0.0225
# epoch  10: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  11: train D loss: 0.3719, train F loss: 1.0933, acc 0.6106, lambda 0.0250
# epoch  11: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  12: train D loss: 0.3749, train F loss: 1.0843, acc 0.6204, lambda 0.0275
# epoch  12: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  13: train D loss: 0.3707, train F loss: 1.0302, acc 0.6342, lambda 0.0300
# epoch  13: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  14: train D loss: 0.3978, train F loss: 0.9911, acc 0.6506, lambda 0.0325
# epoch  14: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  15: train D loss: 0.4167, train F loss: 0.9500, acc 0.6586, lambda 0.0350
# epoch  15: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  16: train D loss: 0.4269, train F loss: 0.9189, acc 0.6690, lambda 0.0375
# epoch  16: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  17: train D loss: 0.4266, train F loss: 0.8870, acc 0.6830, lambda 0.0400
# epoch  17: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  18: train D loss: 0.4286, train F loss: 0.8188, acc 0.7106, lambda 0.0425
# epoch  18: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  19: train D loss: 0.4398, train F loss: 0.8090, acc 0.7032, lambda 0.0450
# epoch  19: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  20: train D loss: 0.4416, train F loss: 0.7598, acc 0.7212, lambda 0.0475
# epoch  20: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  21: train D loss: 0.4356, train F loss: 0.7263, acc 0.7354, lambda 0.0500
# epoch  21: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  22: train D loss: 0.4538, train F loss: 0.7187, acc 0.7334, lambda 0.0525
# epoch  22: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  23: train D loss: 0.4530, train F loss: 0.6749, acc 0.7510, lambda 0.0549
# epoch  23: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  24: train D loss: 0.4721, train F loss: 0.6566, acc 0.7564, lambda 0.0574
# epoch  24: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  25: train D loss: 0.4479, train F loss: 0.5897, acc 0.7766, lambda 0.0599
# epoch  25: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  26: train D loss: 0.4600, train F loss: 0.5631, acc 0.7814, lambda 0.0624
# epoch  26: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  27: train D loss: 0.4548, train F loss: 0.5614, acc 0.7912, lambda 0.0649
# epoch  27: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  28: train D loss: 0.4543, train F loss: 0.5105, acc 0.8014, lambda 0.0674
# epoch  28: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  29: train D loss: 0.4718, train F loss: 0.4956, acc 0.8014, lambda 0.0699
# epoch  29: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  30: train D loss: 0.4703, train F loss: 0.4550, acc 0.8202, lambda 0.0724
# epoch  30: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  31: train D loss: 0.4672, train F loss: 0.4209, acc 0.8308, lambda 0.0749
# epoch  31: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  32: train D loss: 0.4718, train F loss: 0.4138, acc 0.8392, lambda 0.0773
# epoch  32: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  33: train D loss: 0.4668, train F loss: 0.3561, acc 0.8458, lambda 0.0798
# epoch  33: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  34: train D loss: 0.4500, train F loss: 0.3424, acc 0.8554, lambda 0.0823
# epoch  34: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  35: train D loss: 0.4825, train F loss: 0.3159, acc 0.8690, lambda 0.0848
# epoch  35: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  36: train D loss: 0.4769, train F loss: 0.3320, acc 0.8588, lambda 0.0873
# epoch  36: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  37: train D loss: 0.4705, train F loss: 0.2777, acc 0.8732, lambda 0.0898
# epoch  37: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  38: train D loss: 0.4785, train F loss: 0.2653, acc 0.8874, lambda 0.0922
# epoch  38: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  39: train D loss: 0.4878, train F loss: 0.2208, acc 0.8958, lambda 0.0947
# epoch  39: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  40: train D loss: 0.4860, train F loss: 0.2298, acc 0.8870, lambda 0.0972
# epoch  40: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  41: train D loss: 0.4919, train F loss: 0.2306, acc 0.8928, lambda 0.0997
# epoch  41: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  42: train D loss: 0.4798, train F loss: 0.2092, acc 0.8998, lambda 0.1021
# epoch  42: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  43: train D loss: 0.5048, train F loss: 0.1877, acc 0.9046, lambda 0.1046
# epoch  43: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  44: train D loss: 0.5038, train F loss: 0.1770, acc 0.9076, lambda 0.1071
# epoch  44: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  45: train D loss: 0.5001, train F loss: 0.1410, acc 0.9152, lambda 0.1096
# epoch  45: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  46: train D loss: 0.5047, train F loss: 0.1403, acc 0.9172, lambda 0.1120
# epoch  46: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  47: train D loss: 0.5033, train F loss: 0.1448, acc 0.9164, lambda 0.1145
# epoch  47: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  48: train D loss: 0.5201, train F loss: 0.1452, acc 0.9114, lambda 0.1170
# epoch  48: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  49: train D loss: 0.5095, train F loss: 0.1274, acc 0.9194, lambda 0.1194
# epoch  49: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  50: train D loss: 0.5162, train F loss: 0.1077, acc 0.9232, lambda 0.1219
# epoch  50: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  51: train D loss: 0.5159, train F loss: 0.1056, acc 0.9236, lambda 0.1244
# epoch  51: lr_D:0.00100, lr_F:0.00100, lr_C:0.00100
# epoch  52: train D loss: 0.5276, train F loss: 0.0882, acc 0.9272, lambda 0.1268
# epoch  52: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  53: train D loss: 0.5159, train F loss: 0.0708, acc 0.9346, lambda 0.1293
# epoch  53: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  54: train D loss: 0.5399, train F loss: 0.0700, acc 0.9330, lambda 0.1317
# epoch  54: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  55: train D loss: 0.5323, train F loss: 0.0524, acc 0.9374, lambda 0.1342
# epoch  55: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  56: train D loss: 0.5280, train F loss: 0.0463, acc 0.9354, lambda 0.1366
# epoch  56: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  57: train D loss: 0.5354, train F loss: 0.0587, acc 0.9328, lambda 0.1391
# epoch  57: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  58: train D loss: 0.5489, train F loss: 0.0148, acc 0.9442, lambda 0.1415
# epoch  58: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  59: train D loss: 0.5440, train F loss: 0.0331, acc 0.9402, lambda 0.1440
# epoch  59: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  60: train D loss: 0.5450, train F loss: 0.0014, acc 0.9488, lambda 0.1464
# epoch  60: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  61: train D loss: 0.5554, train F loss: 0.0353, acc 0.9368, lambda 0.1489
# epoch  61: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  62: train D loss: 0.5296, train F loss: 0.0296, acc 0.9396, lambda 0.1513
# epoch  62: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  63: train D loss: 0.5448, train F loss: -0.0029, acc 0.9502, lambda 0.1538
# epoch  63: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  64: train D loss: 0.5446, train F loss: 0.0075, acc 0.9474, lambda 0.1562
# epoch  64: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  65: train D loss: 0.5486, train F loss: -0.0131, acc 0.9478, lambda 0.1586
# epoch  65: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  66: train D loss: 0.5573, train F loss: -0.0125, acc 0.9440, lambda 0.1611
# epoch  66: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  67: train D loss: 0.5608, train F loss: -0.0181, acc 0.9478, lambda 0.1635
# epoch  67: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  68: train D loss: 0.5534, train F loss: -0.0361, acc 0.9542, lambda 0.1660
# epoch  68: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  69: train D loss: 0.5548, train F loss: -0.0332, acc 0.9546, lambda 0.1684
# epoch  69: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  70: train D loss: 0.5690, train F loss: -0.0433, acc 0.9546, lambda 0.1708
# epoch  70: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  71: train D loss: 0.5721, train F loss: -0.0507, acc 0.9542, lambda 0.1732
# epoch  71: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  72: train D loss: 0.5770, train F loss: -0.0507, acc 0.9490, lambda 0.1757
# epoch  72: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  73: train D loss: 0.5661, train F loss: -0.0468, acc 0.9494, lambda 0.1781
# epoch  73: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  74: train D loss: 0.5666, train F loss: -0.0490, acc 0.9532, lambda 0.1805
# epoch  74: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  75: train D loss: 0.5533, train F loss: -0.0360, acc 0.9524, lambda 0.1829
# epoch  75: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  76: train D loss: 0.5704, train F loss: -0.0575, acc 0.9478, lambda 0.1853
# epoch  76: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  77: train D loss: 0.5783, train F loss: -0.0681, acc 0.9528, lambda 0.1877
# epoch  77: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  78: train D loss: 0.5775, train F loss: -0.0654, acc 0.9506, lambda 0.1902
# epoch  78: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  79: train D loss: 0.5748, train F loss: -0.0942, acc 0.9596, lambda 0.1926
# epoch  79: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  80: train D loss: 0.5853, train F loss: -0.0997, acc 0.9590, lambda 0.1950
# epoch  80: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  81: train D loss: 0.5822, train F loss: -0.0820, acc 0.9544, lambda 0.1974
# epoch  81: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  82: train D loss: 0.5875, train F loss: -0.1038, acc 0.9626, lambda 0.1998
# epoch  82: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  83: train D loss: 0.5780, train F loss: -0.0856, acc 0.9502, lambda 0.2022
# epoch  83: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  84: train D loss: 0.5789, train F loss: -0.1064, acc 0.9600, lambda 0.2046
# epoch  84: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  85: train D loss: 0.5895, train F loss: -0.1042, acc 0.9538, lambda 0.2070
# epoch  85: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  86: train D loss: 0.5846, train F loss: -0.1105, acc 0.9584, lambda 0.2094
# epoch  86: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  87: train D loss: 0.5799, train F loss: -0.1091, acc 0.9606, lambda 0.2117
# epoch  87: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  88: train D loss: 0.5895, train F loss: -0.1236, acc 0.9608, lambda 0.2141
# epoch  88: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  89: train D loss: 0.5932, train F loss: -0.1119, acc 0.9552, lambda 0.2165
# epoch  89: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  90: train D loss: 0.5785, train F loss: -0.0972, acc 0.9538, lambda 0.2189
# epoch  90: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  91: train D loss: 0.5908, train F loss: -0.1308, acc 0.9598, lambda 0.2213
# epoch  91: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  92: train D loss: 0.5988, train F loss: -0.1336, acc 0.9570, lambda 0.2237
# epoch  92: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  93: train D loss: 0.5906, train F loss: -0.1214, acc 0.9604, lambda 0.2260
# epoch  93: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  94: train D loss: 0.5889, train F loss: -0.1362, acc 0.9570, lambda 0.2284
# epoch  94: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  95: train D loss: 0.5790, train F loss: -0.1296, acc 0.9560, lambda 0.2308
# epoch  95: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  96: train D loss: 0.5841, train F loss: -0.1529, acc 0.9634, lambda 0.2331
# epoch  96: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  97: train D loss: 0.5911, train F loss: -0.1307, acc 0.9560, lambda 0.2355
# epoch  97: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  98: train D loss: 0.5925, train F loss: -0.1643, acc 0.9640, lambda 0.2379
# epoch  98: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch  99: train D loss: 0.5965, train F loss: -0.1677, acc 0.9648, lambda 0.2402
# epoch  99: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch 100: train D loss: 0.6035, train F loss: -0.1704, acc 0.9634, lambda 0.2426
# epoch 100: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch 101: train D loss: 0.6027, train F loss: -0.1815, acc 0.9682, lambda 0.2449
# epoch 101: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch 102: train D loss: 0.6198, train F loss: -0.1856, acc 0.9656, lambda 0.2473
# epoch 102: lr_D:0.00100, lr_F:0.00100, lr_C:0.00090
# epoch 103: train D loss: 0.6195, train F loss: -0.1942, acc 0.9654, lambda 0.2496
# epoch 103: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 104: train D loss: 0.6207, train F loss: -0.1875, acc 0.9614, lambda 0.2520
# epoch 104: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 105: train D loss: 0.6048, train F loss: -0.1917, acc 0.9662, lambda 0.2543
# epoch 105: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 106: train D loss: 0.6075, train F loss: -0.2116, acc 0.9712, lambda 0.2566
# epoch 106: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 107: train D loss: 0.6078, train F loss: -0.2092, acc 0.9676, lambda 0.2590
# epoch 107: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 108: train D loss: 0.6133, train F loss: -0.2133, acc 0.9670, lambda 0.2613
# epoch 108: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 109: train D loss: 0.6159, train F loss: -0.2141, acc 0.9664, lambda 0.2636
# epoch 109: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 110: train D loss: 0.6181, train F loss: -0.2083, acc 0.9642, lambda 0.2659
# epoch 110: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 111: train D loss: 0.6123, train F loss: -0.2157, acc 0.9644, lambda 0.2683
# epoch 111: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 112: train D loss: 0.6179, train F loss: -0.2225, acc 0.9654, lambda 0.2706
# epoch 112: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 113: train D loss: 0.6083, train F loss: -0.2108, acc 0.9634, lambda 0.2729
# epoch 113: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 114: train D loss: 0.6219, train F loss: -0.2247, acc 0.9668, lambda 0.2752
# epoch 114: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 115: train D loss: 0.6157, train F loss: -0.2315, acc 0.9666, lambda 0.2775
# epoch 115: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 116: train D loss: 0.6137, train F loss: -0.2424, acc 0.9716, lambda 0.2798
# epoch 116: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 117: train D loss: 0.6129, train F loss: -0.2368, acc 0.9670, lambda 0.2821
# epoch 117: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 118: train D loss: 0.6329, train F loss: -0.2550, acc 0.9682, lambda 0.2844
# epoch 118: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 119: train D loss: 0.6198, train F loss: -0.2379, acc 0.9670, lambda 0.2867
# epoch 119: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 120: train D loss: 0.6206, train F loss: -0.2567, acc 0.9704, lambda 0.2890
# epoch 120: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 121: train D loss: 0.6256, train F loss: -0.2597, acc 0.9696, lambda 0.2913
# epoch 121: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 122: train D loss: 0.6193, train F loss: -0.2671, acc 0.9724, lambda 0.2936
# epoch 122: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 123: train D loss: 0.6276, train F loss: -0.2540, acc 0.9662, lambda 0.2959
# epoch 123: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 124: train D loss: 0.6122, train F loss: -0.2591, acc 0.9688, lambda 0.2982
# epoch 124: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 125: train D loss: 0.6366, train F loss: -0.2786, acc 0.9688, lambda 0.3004
# epoch 125: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 126: train D loss: 0.6306, train F loss: -0.2878, acc 0.9730, lambda 0.3027
# epoch 126: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 127: train D loss: 0.6291, train F loss: -0.2866, acc 0.9708, lambda 0.3050
# epoch 127: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 128: train D loss: 0.6133, train F loss: -0.2674, acc 0.9688, lambda 0.3072
# epoch 128: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 129: train D loss: 0.6298, train F loss: -0.2782, acc 0.9686, lambda 0.3095
# epoch 129: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 130: train D loss: 0.6197, train F loss: -0.2725, acc 0.9652, lambda 0.3118
# epoch 130: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 131: train D loss: 0.6325, train F loss: -0.2888, acc 0.9686, lambda 0.3140
# epoch 131: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 132: train D loss: 0.6219, train F loss: -0.2780, acc 0.9642, lambda 0.3163
# epoch 132: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 133: train D loss: 0.6229, train F loss: -0.2868, acc 0.9650, lambda 0.3185
# epoch 133: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 134: train D loss: 0.6264, train F loss: -0.3175, acc 0.9752, lambda 0.3208
# epoch 134: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 135: train D loss: 0.6258, train F loss: -0.2991, acc 0.9700, lambda 0.3230
# epoch 135: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 136: train D loss: 0.6260, train F loss: -0.3034, acc 0.9696, lambda 0.3252
# epoch 136: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 137: train D loss: 0.6281, train F loss: -0.3026, acc 0.9668, lambda 0.3275
# epoch 137: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 138: train D loss: 0.6309, train F loss: -0.3180, acc 0.9714, lambda 0.3297
# epoch 138: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 139: train D loss: 0.6229, train F loss: -0.3178, acc 0.9718, lambda 0.3319
# epoch 139: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 140: train D loss: 0.6423, train F loss: -0.3392, acc 0.9726, lambda 0.3342
# epoch 140: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 141: train D loss: 0.6316, train F loss: -0.3289, acc 0.9718, lambda 0.3364
# epoch 141: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 142: train D loss: 0.6385, train F loss: -0.3358, acc 0.9706, lambda 0.3386
# epoch 142: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 143: train D loss: 0.6373, train F loss: -0.3364, acc 0.9722, lambda 0.3408
# epoch 143: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 144: train D loss: 0.6321, train F loss: -0.3385, acc 0.9718, lambda 0.3430
# epoch 144: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 145: train D loss: 0.6364, train F loss: -0.3456, acc 0.9752, lambda 0.3452
# epoch 145: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 146: train D loss: 0.6365, train F loss: -0.3457, acc 0.9736, lambda 0.3474
# epoch 146: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 147: train D loss: 0.6431, train F loss: -0.3640, acc 0.9748, lambda 0.3496
# epoch 147: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 148: train D loss: 0.6481, train F loss: -0.3531, acc 0.9722, lambda 0.3518
# epoch 148: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 149: train D loss: 0.6377, train F loss: -0.3369, acc 0.9636, lambda 0.3540
# epoch 149: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 150: train D loss: 0.6428, train F loss: -0.3701, acc 0.9738, lambda 0.3562
# epoch 150: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 151: train D loss: 0.6353, train F loss: -0.3683, acc 0.9764, lambda 0.3584
# epoch 151: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 152: train D loss: 0.6359, train F loss: -0.3649, acc 0.9760, lambda 0.3605
# epoch 152: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 153: train D loss: 0.6366, train F loss: -0.3460, acc 0.9664, lambda 0.3627
# epoch 153: lr_D:0.00100, lr_F:0.00100, lr_C:0.00081
# epoch 154: train D loss: 0.6367, train F loss: -0.3642, acc 0.9730, lambda 0.3649
# epoch 154: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 155: train D loss: 0.6396, train F loss: -0.3646, acc 0.9696, lambda 0.3670
# epoch 155: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 156: train D loss: 0.6345, train F loss: -0.3658, acc 0.9706, lambda 0.3692
# epoch 156: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 157: train D loss: 0.6385, train F loss: -0.3854, acc 0.9778, lambda 0.3714
# epoch 157: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 158: train D loss: 0.6433, train F loss: -0.3872, acc 0.9744, lambda 0.3735
# epoch 158: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 159: train D loss: 0.6408, train F loss: -0.3901, acc 0.9730, lambda 0.3757
# epoch 159: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 160: train D loss: 0.6343, train F loss: -0.3906, acc 0.9756, lambda 0.3778
# epoch 160: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 161: train D loss: 0.6516, train F loss: -0.4102, acc 0.9748, lambda 0.3799
# epoch 161: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 162: train D loss: 0.6448, train F loss: -0.4112, acc 0.9762, lambda 0.3821
# epoch 162: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 163: train D loss: 0.6499, train F loss: -0.4063, acc 0.9716, lambda 0.3842
# epoch 163: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 164: train D loss: 0.6450, train F loss: -0.4000, acc 0.9718, lambda 0.3863
# epoch 164: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 165: train D loss: 0.6509, train F loss: -0.4100, acc 0.9728, lambda 0.3885
# epoch 165: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 166: train D loss: 0.6482, train F loss: -0.4145, acc 0.9728, lambda 0.3906
# epoch 166: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 167: train D loss: 0.6411, train F loss: -0.4077, acc 0.9748, lambda 0.3927
# epoch 167: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 168: train D loss: 0.6412, train F loss: -0.4097, acc 0.9744, lambda 0.3948
# epoch 168: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 169: train D loss: 0.6376, train F loss: -0.4200, acc 0.9770, lambda 0.3969
# epoch 169: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 170: train D loss: 0.6428, train F loss: -0.4185, acc 0.9710, lambda 0.3990
# epoch 170: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 171: train D loss: 0.6421, train F loss: -0.4139, acc 0.9734, lambda 0.4011
# epoch 171: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 172: train D loss: 0.6412, train F loss: -0.4392, acc 0.9776, lambda 0.4032
# epoch 172: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 173: train D loss: 0.6434, train F loss: -0.4388, acc 0.9748, lambda 0.4053
# epoch 173: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 174: train D loss: 0.6431, train F loss: -0.4492, acc 0.9790, lambda 0.4074
# epoch 174: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 175: train D loss: 0.6527, train F loss: -0.4405, acc 0.9712, lambda 0.4095
# epoch 175: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 176: train D loss: 0.6441, train F loss: -0.4308, acc 0.9706, lambda 0.4116
# epoch 176: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 177: train D loss: 0.6382, train F loss: -0.4443, acc 0.9768, lambda 0.4136
# epoch 177: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 178: train D loss: 0.6487, train F loss: -0.4599, acc 0.9772, lambda 0.4157
# epoch 178: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 179: train D loss: 0.6490, train F loss: -0.4507, acc 0.9746, lambda 0.4178
# epoch 179: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 180: train D loss: 0.6523, train F loss: -0.4469, acc 0.9708, lambda 0.4198
# epoch 180: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 181: train D loss: 0.6449, train F loss: -0.4595, acc 0.9764, lambda 0.4219
# epoch 181: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 182: train D loss: 0.6398, train F loss: -0.4502, acc 0.9738, lambda 0.4240
# epoch 182: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 183: train D loss: 0.6501, train F loss: -0.4672, acc 0.9752, lambda 0.4260
# epoch 183: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 184: train D loss: 0.6484, train F loss: -0.4647, acc 0.9766, lambda 0.4280
# epoch 184: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 185: train D loss: 0.6474, train F loss: -0.4829, acc 0.9802, lambda 0.4301
# epoch 185: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 186: train D loss: 0.6517, train F loss: -0.4809, acc 0.9756, lambda 0.4321
# epoch 186: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 187: train D loss: 0.6502, train F loss: -0.4785, acc 0.9766, lambda 0.4342
# epoch 187: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 188: train D loss: 0.6485, train F loss: -0.4741, acc 0.9760, lambda 0.4362
# epoch 188: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 189: train D loss: 0.6554, train F loss: -0.4711, acc 0.9684, lambda 0.4382
# epoch 189: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 190: train D loss: 0.6530, train F loss: -0.4954, acc 0.9772, lambda 0.4402
# epoch 190: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 191: train D loss: 0.6562, train F loss: -0.5038, acc 0.9762, lambda 0.4422
# epoch 191: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 192: train D loss: 0.6484, train F loss: -0.4790, acc 0.9732, lambda 0.4442
# epoch 192: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 193: train D loss: 0.6574, train F loss: -0.5132, acc 0.9794, lambda 0.4462
# epoch 193: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 194: train D loss: 0.6478, train F loss: -0.5014, acc 0.9784, lambda 0.4482
# epoch 194: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 195: train D loss: 0.6506, train F loss: -0.5036, acc 0.9764, lambda 0.4502
# epoch 195: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 196: train D loss: 0.6574, train F loss: -0.4964, acc 0.9716, lambda 0.4522
# epoch 196: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 197: train D loss: 0.6557, train F loss: -0.5198, acc 0.9780, lambda 0.4542
# epoch 197: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 198: train D loss: 0.6516, train F loss: -0.5049, acc 0.9738, lambda 0.4562
# epoch 198: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 199: train D loss: 0.6497, train F loss: -0.5231, acc 0.9780, lambda 0.4582
# epoch 199: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 200: train D loss: 0.6514, train F loss: -0.5157, acc 0.9736, lambda 0.4601
# epoch 200: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 201: train D loss: 0.6564, train F loss: -0.5290, acc 0.9778, lambda 0.4621
# epoch 201: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 202: train D loss: 0.6604, train F loss: -0.5356, acc 0.9778, lambda 0.4641
# epoch 202: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 203: train D loss: 0.6572, train F loss: -0.5287, acc 0.9794, lambda 0.4660
# epoch 203: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 204: train D loss: 0.6619, train F loss: -0.5289, acc 0.9740, lambda 0.4680
# epoch 204: lr_D:0.00100, lr_F:0.00100, lr_C:0.00073
# epoch 205: train D loss: 0.6605, train F loss: -0.5406, acc 0.9746, lambda 0.4699
# epoch 205: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 206: train D loss: 0.6563, train F loss: -0.5343, acc 0.9766, lambda 0.4719
# epoch 206: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 207: train D loss: 0.6514, train F loss: -0.5400, acc 0.9798, lambda 0.4738
# epoch 207: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 208: train D loss: 0.6571, train F loss: -0.5439, acc 0.9762, lambda 0.4758
# epoch 208: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 209: train D loss: 0.6548, train F loss: -0.5389, acc 0.9748, lambda 0.4777
# epoch 209: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 210: train D loss: 0.6639, train F loss: -0.5547, acc 0.9760, lambda 0.4796
# epoch 210: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 211: train D loss: 0.6544, train F loss: -0.5382, acc 0.9732, lambda 0.4815
# epoch 211: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 212: train D loss: 0.6570, train F loss: -0.5499, acc 0.9750, lambda 0.4835
# epoch 212: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 213: train D loss: 0.6629, train F loss: -0.5721, acc 0.9786, lambda 0.4854
# epoch 213: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 214: train D loss: 0.6612, train F loss: -0.5824, acc 0.9816, lambda 0.4873
# epoch 214: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 215: train D loss: 0.6619, train F loss: -0.5716, acc 0.9766, lambda 0.4892
# epoch 215: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 216: train D loss: 0.6579, train F loss: -0.5659, acc 0.9778, lambda 0.4911
# epoch 216: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 217: train D loss: 0.6524, train F loss: -0.5532, acc 0.9748, lambda 0.4930
# epoch 217: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 218: train D loss: 0.6607, train F loss: -0.5781, acc 0.9800, lambda 0.4949
# epoch 218: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 219: train D loss: 0.6627, train F loss: -0.5836, acc 0.9798, lambda 0.4968
# epoch 219: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 220: train D loss: 0.6604, train F loss: -0.5800, acc 0.9778, lambda 0.4986
# epoch 220: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 221: train D loss: 0.6588, train F loss: -0.5836, acc 0.9802, lambda 0.5005
# epoch 221: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 222: train D loss: 0.6629, train F loss: -0.5942, acc 0.9818, lambda 0.5024
# epoch 222: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 223: train D loss: 0.6578, train F loss: -0.5723, acc 0.9756, lambda 0.5043
# epoch 223: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 224: train D loss: 0.6650, train F loss: -0.5962, acc 0.9792, lambda 0.5061
# epoch 224: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 225: train D loss: 0.6589, train F loss: -0.5956, acc 0.9790, lambda 0.5080
# epoch 225: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 226: train D loss: 0.6617, train F loss: -0.5939, acc 0.9786, lambda 0.5098
# epoch 226: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 227: train D loss: 0.6615, train F loss: -0.6057, acc 0.9798, lambda 0.5117
# epoch 227: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 228: train D loss: 0.6604, train F loss: -0.6014, acc 0.9806, lambda 0.5135
# epoch 228: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 229: train D loss: 0.6549, train F loss: -0.5899, acc 0.9772, lambda 0.5154
# epoch 229: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 230: train D loss: 0.6673, train F loss: -0.6071, acc 0.9766, lambda 0.5172
# epoch 230: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 231: train D loss: 0.6614, train F loss: -0.6125, acc 0.9786, lambda 0.5190
# epoch 231: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 232: train D loss: 0.6606, train F loss: -0.6240, acc 0.9816, lambda 0.5208
# epoch 232: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 233: train D loss: 0.6538, train F loss: -0.6005, acc 0.9778, lambda 0.5227
# epoch 233: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 234: train D loss: 0.6642, train F loss: -0.6203, acc 0.9800, lambda 0.5245
# epoch 234: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 235: train D loss: 0.6635, train F loss: -0.6263, acc 0.9806, lambda 0.5263
# epoch 235: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 236: train D loss: 0.6679, train F loss: -0.6381, acc 0.9812, lambda 0.5281
# epoch 236: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 237: train D loss: 0.6626, train F loss: -0.6152, acc 0.9768, lambda 0.5299
# epoch 237: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 238: train D loss: 0.6647, train F loss: -0.6191, acc 0.9756, lambda 0.5317
# epoch 238: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 239: train D loss: 0.6663, train F loss: -0.6333, acc 0.9784, lambda 0.5335
# epoch 239: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 240: train D loss: 0.6568, train F loss: -0.6223, acc 0.9776, lambda 0.5353
# epoch 240: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 241: train D loss: 0.6640, train F loss: -0.6279, acc 0.9782, lambda 0.5370
# epoch 241: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 242: train D loss: 0.6668, train F loss: -0.6530, acc 0.9810, lambda 0.5388
# epoch 242: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 243: train D loss: 0.6660, train F loss: -0.6501, acc 0.9816, lambda 0.5406
# epoch 243: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 244: train D loss: 0.6622, train F loss: -0.6312, acc 0.9772, lambda 0.5424
# epoch 244: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 245: train D loss: 0.6591, train F loss: -0.6388, acc 0.9798, lambda 0.5441
# epoch 245: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 246: train D loss: 0.6700, train F loss: -0.6522, acc 0.9780, lambda 0.5459
# epoch 246: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 247: train D loss: 0.6550, train F loss: -0.6354, acc 0.9770, lambda 0.5476
# epoch 247: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 248: train D loss: 0.6667, train F loss: -0.6440, acc 0.9764, lambda 0.5494
# epoch 248: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 249: train D loss: 0.6643, train F loss: -0.6605, acc 0.9798, lambda 0.5511
# epoch 249: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 250: train D loss: 0.6642, train F loss: -0.6592, acc 0.9800, lambda 0.5529
# epoch 250: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 251: train D loss: 0.6669, train F loss: -0.6755, acc 0.9816, lambda 0.5546
# epoch 251: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 252: train D loss: 0.6667, train F loss: -0.6726, acc 0.9796, lambda 0.5563
# epoch 252: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 253: train D loss: 0.6592, train F loss: -0.6789, acc 0.9858, lambda 0.5581
# epoch 253: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 254: train D loss: 0.6644, train F loss: -0.6613, acc 0.9786, lambda 0.5598
# epoch 254: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 255: train D loss: 0.6654, train F loss: -0.6778, acc 0.9814, lambda 0.5615
# epoch 255: lr_D:0.00100, lr_F:0.00100, lr_C:0.00066
# epoch 256: train D loss: 0.6690, train F loss: -0.6912, acc 0.9832, lambda 0.5632
# epoch 256: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 257: train D loss: 0.6644, train F loss: -0.6837, acc 0.9814, lambda 0.5649
# epoch 257: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 258: train D loss: 0.6693, train F loss: -0.6939, acc 0.9818, lambda 0.5666
# epoch 258: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 259: train D loss: 0.6647, train F loss: -0.6783, acc 0.9794, lambda 0.5683
# epoch 259: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 260: train D loss: 0.6662, train F loss: -0.6886, acc 0.9796, lambda 0.5700
# epoch 260: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 261: train D loss: 0.6605, train F loss: -0.6667, acc 0.9740, lambda 0.5717
# epoch 261: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 262: train D loss: 0.6629, train F loss: -0.6856, acc 0.9810, lambda 0.5734
# epoch 262: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 263: train D loss: 0.6665, train F loss: -0.6956, acc 0.9810, lambda 0.5750
# epoch 263: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 264: train D loss: 0.6690, train F loss: -0.7120, acc 0.9836, lambda 0.5767
# epoch 264: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 265: train D loss: 0.6686, train F loss: -0.7034, acc 0.9788, lambda 0.5784
# epoch 265: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 266: train D loss: 0.6696, train F loss: -0.6990, acc 0.9780, lambda 0.5800
# epoch 266: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 267: train D loss: 0.6582, train F loss: -0.6893, acc 0.9796, lambda 0.5817
# epoch 267: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 268: train D loss: 0.6706, train F loss: -0.7091, acc 0.9798, lambda 0.5833
# epoch 268: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 269: train D loss: 0.6630, train F loss: -0.7062, acc 0.9824, lambda 0.5850
# epoch 269: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 270: train D loss: 0.6676, train F loss: -0.7220, acc 0.9816, lambda 0.5866
# epoch 270: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 271: train D loss: 0.6696, train F loss: -0.7115, acc 0.9798, lambda 0.5883
# epoch 271: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 272: train D loss: 0.6698, train F loss: -0.7199, acc 0.9800, lambda 0.5899
# epoch 272: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 273: train D loss: 0.6692, train F loss: -0.7193, acc 0.9784, lambda 0.5915
# epoch 273: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 274: train D loss: 0.6670, train F loss: -0.7286, acc 0.9848, lambda 0.5931
# epoch 274: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 275: train D loss: 0.6660, train F loss: -0.7289, acc 0.9828, lambda 0.5948
# epoch 275: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 276: train D loss: 0.6713, train F loss: -0.7313, acc 0.9790, lambda 0.5964
# epoch 276: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 277: train D loss: 0.6652, train F loss: -0.7119, acc 0.9752, lambda 0.5980
# epoch 277: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 278: train D loss: 0.6676, train F loss: -0.7382, acc 0.9832, lambda 0.5996
# epoch 278: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 279: train D loss: 0.6670, train F loss: -0.7404, acc 0.9836, lambda 0.6012
# epoch 279: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 280: train D loss: 0.6685, train F loss: -0.7336, acc 0.9792, lambda 0.6028
# epoch 280: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 281: train D loss: 0.6637, train F loss: -0.7293, acc 0.9806, lambda 0.6044
# epoch 281: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 282: train D loss: 0.6649, train F loss: -0.7276, acc 0.9788, lambda 0.6060
# epoch 282: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 283: train D loss: 0.6653, train F loss: -0.7363, acc 0.9814, lambda 0.6075
# epoch 283: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 284: train D loss: 0.6718, train F loss: -0.7440, acc 0.9796, lambda 0.6091
# epoch 284: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 285: train D loss: 0.6621, train F loss: -0.7379, acc 0.9828, lambda 0.6107
# epoch 285: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 286: train D loss: 0.6722, train F loss: -0.7428, acc 0.9784, lambda 0.6122
# epoch 286: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 287: train D loss: 0.6674, train F loss: -0.7430, acc 0.9778, lambda 0.6138
# epoch 287: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 288: train D loss: 0.6638, train F loss: -0.7318, acc 0.9764, lambda 0.6154
# epoch 288: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 289: train D loss: 0.6740, train F loss: -0.7728, acc 0.9826, lambda 0.6169
# epoch 289: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 290: train D loss: 0.6674, train F loss: -0.7577, acc 0.9814, lambda 0.6185
# epoch 290: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 291: train D loss: 0.6711, train F loss: -0.7658, acc 0.9820, lambda 0.6200
# epoch 291: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 292: train D loss: 0.6652, train F loss: -0.7553, acc 0.9804, lambda 0.6215
# epoch 292: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 293: train D loss: 0.6652, train F loss: -0.7584, acc 0.9820, lambda 0.6231
# epoch 293: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 294: train D loss: 0.6695, train F loss: -0.7787, acc 0.9856, lambda 0.6246
# epoch 294: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 295: train D loss: 0.6775, train F loss: -0.7844, acc 0.9826, lambda 0.6261
# epoch 295: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 296: train D loss: 0.6708, train F loss: -0.7864, acc 0.9840, lambda 0.6276
# epoch 296: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 297: train D loss: 0.6725, train F loss: -0.7770, acc 0.9824, lambda 0.6291
# epoch 297: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 298: train D loss: 0.6671, train F loss: -0.7689, acc 0.9832, lambda 0.6307
# epoch 298: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 299: train D loss: 0.6673, train F loss: -0.7747, acc 0.9792, lambda 0.6322
# epoch 299: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 300: train D loss: 0.6729, train F loss: -0.7923, acc 0.9836, lambda 0.6337
# epoch 300: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 301: train D loss: 0.6739, train F loss: -0.7874, acc 0.9824, lambda 0.6351
# epoch 301: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 302: train D loss: 0.6745, train F loss: -0.7818, acc 0.9806, lambda 0.6366
# epoch 302: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 303: train D loss: 0.6738, train F loss: -0.7939, acc 0.9812, lambda 0.6381
# epoch 303: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 304: train D loss: 0.6752, train F loss: -0.7902, acc 0.9818, lambda 0.6396
# epoch 304: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 305: train D loss: 0.6723, train F loss: -0.7884, acc 0.9798, lambda 0.6411
# epoch 305: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 306: train D loss: 0.6717, train F loss: -0.8018, acc 0.9836, lambda 0.6425
# epoch 306: lr_D:0.00100, lr_F:0.00100, lr_C:0.00059
# epoch 307: train D loss: 0.6709, train F loss: -0.8059, acc 0.9844, lambda 0.6440
# epoch 307: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 308: train D loss: 0.6696, train F loss: -0.7985, acc 0.9826, lambda 0.6455
# epoch 308: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 309: train D loss: 0.6713, train F loss: -0.8080, acc 0.9852, lambda 0.6469
# epoch 309: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 310: train D loss: 0.6666, train F loss: -0.8109, acc 0.9838, lambda 0.6484
# epoch 310: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 311: train D loss: 0.6746, train F loss: -0.8123, acc 0.9816, lambda 0.6498
# epoch 311: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 312: train D loss: 0.6696, train F loss: -0.7990, acc 0.9772, lambda 0.6513
# epoch 312: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 313: train D loss: 0.6724, train F loss: -0.8250, acc 0.9848, lambda 0.6527
# epoch 313: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 314: train D loss: 0.6715, train F loss: -0.8029, acc 0.9800, lambda 0.6541
# epoch 314: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 315: train D loss: 0.6682, train F loss: -0.8112, acc 0.9836, lambda 0.6556
# epoch 315: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 316: train D loss: 0.6730, train F loss: -0.8196, acc 0.9834, lambda 0.6570
# epoch 316: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 317: train D loss: 0.6741, train F loss: -0.8243, acc 0.9856, lambda 0.6584
# epoch 317: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 318: train D loss: 0.6741, train F loss: -0.8235, acc 0.9820, lambda 0.6598
# epoch 318: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 319: train D loss: 0.6711, train F loss: -0.8242, acc 0.9816, lambda 0.6612
# epoch 319: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 320: train D loss: 0.6761, train F loss: -0.8302, acc 0.9820, lambda 0.6626
# epoch 320: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 321: train D loss: 0.6748, train F loss: -0.8367, acc 0.9838, lambda 0.6640
# epoch 321: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 322: train D loss: 0.6678, train F loss: -0.8191, acc 0.9826, lambda 0.6654
# epoch 322: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 323: train D loss: 0.6742, train F loss: -0.8272, acc 0.9788, lambda 0.6668
# epoch 323: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 324: train D loss: 0.6747, train F loss: -0.8430, acc 0.9836, lambda 0.6682
# epoch 324: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 325: train D loss: 0.6694, train F loss: -0.8259, acc 0.9806, lambda 0.6696
# epoch 325: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 326: train D loss: 0.6696, train F loss: -0.8198, acc 0.9790, lambda 0.6710
# epoch 326: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 327: train D loss: 0.6757, train F loss: -0.8320, acc 0.9782, lambda 0.6723
# epoch 327: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 328: train D loss: 0.6730, train F loss: -0.8466, acc 0.9830, lambda 0.6737
# epoch 328: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 329: train D loss: 0.6730, train F loss: -0.8544, acc 0.9850, lambda 0.6751
# epoch 329: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 330: train D loss: 0.6751, train F loss: -0.8479, acc 0.9822, lambda 0.6764
# epoch 330: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 331: train D loss: 0.6697, train F loss: -0.8435, acc 0.9828, lambda 0.6778
# epoch 331: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 332: train D loss: 0.6779, train F loss: -0.8647, acc 0.9832, lambda 0.6791
# epoch 332: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 333: train D loss: 0.6769, train F loss: -0.8572, acc 0.9840, lambda 0.6805
# epoch 333: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 334: train D loss: 0.6692, train F loss: -0.8450, acc 0.9830, lambda 0.6818
# epoch 334: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 335: train D loss: 0.6685, train F loss: -0.8454, acc 0.9830, lambda 0.6832
# epoch 335: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 336: train D loss: 0.6676, train F loss: -0.8498, acc 0.9830, lambda 0.6845
# epoch 336: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 337: train D loss: 0.6723, train F loss: -0.8511, acc 0.9810, lambda 0.6858
# epoch 337: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 338: train D loss: 0.6692, train F loss: -0.8542, acc 0.9836, lambda 0.6871
# epoch 338: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 339: train D loss: 0.6763, train F loss: -0.8752, acc 0.9860, lambda 0.6884
# epoch 339: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 340: train D loss: 0.6756, train F loss: -0.8651, acc 0.9826, lambda 0.6898
# epoch 340: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 341: train D loss: 0.6760, train F loss: -0.8842, acc 0.9876, lambda 0.6911
# epoch 341: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 342: train D loss: 0.6724, train F loss: -0.8446, acc 0.9770, lambda 0.6924
# epoch 342: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 343: train D loss: 0.6703, train F loss: -0.8704, acc 0.9834, lambda 0.6937
# epoch 343: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 344: train D loss: 0.6721, train F loss: -0.8692, acc 0.9848, lambda 0.6950
# epoch 344: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 345: train D loss: 0.6685, train F loss: -0.8597, acc 0.9824, lambda 0.6963
# epoch 345: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 346: train D loss: 0.6749, train F loss: -0.8770, acc 0.9850, lambda 0.6975
# epoch 346: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 347: train D loss: 0.6713, train F loss: -0.8783, acc 0.9828, lambda 0.6988
# epoch 347: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 348: train D loss: 0.6772, train F loss: -0.8803, acc 0.9826, lambda 0.7001
# epoch 348: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 349: train D loss: 0.6745, train F loss: -0.8972, acc 0.9854, lambda 0.7014
# epoch 349: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 350: train D loss: 0.6796, train F loss: -0.8982, acc 0.9828, lambda 0.7026
# epoch 350: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 351: train D loss: 0.6709, train F loss: -0.8909, acc 0.9860, lambda 0.7039
# epoch 351: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 352: train D loss: 0.6779, train F loss: -0.8963, acc 0.9848, lambda 0.7052
# epoch 352: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 353: train D loss: 0.6733, train F loss: -0.8928, acc 0.9860, lambda 0.7064
# epoch 353: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 354: train D loss: 0.6758, train F loss: -0.9045, acc 0.9864, lambda 0.7077
# epoch 354: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 355: train D loss: 0.6683, train F loss: -0.8892, acc 0.9846, lambda 0.7089
# epoch 355: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 356: train D loss: 0.6776, train F loss: -0.9098, acc 0.9866, lambda 0.7102
# epoch 356: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 357: train D loss: 0.6797, train F loss: -0.9000, acc 0.9800, lambda 0.7114
# epoch 357: lr_D:0.00100, lr_F:0.00100, lr_C:0.00053
# epoch 358: train D loss: 0.6747, train F loss: -0.8939, acc 0.9802, lambda 0.7126
# epoch 358: lr_D:0.00100, lr_F:0.00100, lr_C:0.00048
# epoch 359: train D loss: 0.6719, train F loss: -0.8998, acc 0.9824, lambda 0.7139
# ...
# epoch 1883: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1884: train D loss: 0.6922, train F loss: -1.3734, acc 0.9960, lambda 0.9998
# epoch 1884: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1885: train D loss: 0.6917, train F loss: -1.3732, acc 0.9966, lambda 0.9998
# epoch 1885: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1886: train D loss: 0.6920, train F loss: -1.3694, acc 0.9948, lambda 0.9998
# epoch 1886: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1887: train D loss: 0.6912, train F loss: -1.3729, acc 0.9962, lambda 0.9998
# epoch 1887: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1888: train D loss: 0.6909, train F loss: -1.3718, acc 0.9964, lambda 0.9998
# epoch 1888: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1889: train D loss: 0.6911, train F loss: -1.3717, acc 0.9966, lambda 0.9998
# epoch 1889: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1890: train D loss: 0.6923, train F loss: -1.3749, acc 0.9962, lambda 0.9998
# epoch 1890: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1891: train D loss: 0.6927, train F loss: -1.3728, acc 0.9954, lambda 0.9998
# epoch 1891: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1892: train D loss: 0.6927, train F loss: -1.3768, acc 0.9970, lambda 0.9998
# epoch 1892: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1893: train D loss: 0.6934, train F loss: -1.3732, acc 0.9956, lambda 0.9998
# epoch 1893: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1894: train D loss: 0.6931, train F loss: -1.3758, acc 0.9960, lambda 0.9998
# epoch 1894: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1895: train D loss: 0.6938, train F loss: -1.3757, acc 0.9956, lambda 0.9998
# epoch 1895: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1896: train D loss: 0.6930, train F loss: -1.3775, acc 0.9974, lambda 0.9998
# epoch 1896: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1897: train D loss: 0.6935, train F loss: -1.3764, acc 0.9962, lambda 0.9998
# epoch 1897: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1898: train D loss: 0.6922, train F loss: -1.3671, acc 0.9946, lambda 0.9998
# epoch 1898: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1899: train D loss: 0.6928, train F loss: -1.3748, acc 0.9966, lambda 0.9998
# epoch 1899: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1900: train D loss: 0.6932, train F loss: -1.3733, acc 0.9948, lambda 0.9998
# epoch 1900: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1901: train D loss: 0.6924, train F loss: -1.3734, acc 0.9960, lambda 0.9999
# epoch 1901: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1902: train D loss: 0.6923, train F loss: -1.3744, acc 0.9970, lambda 0.9999
# epoch 1902: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1903: train D loss: 0.6929, train F loss: -1.3743, acc 0.9952, lambda 0.9999
# epoch 1903: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1904: train D loss: 0.6930, train F loss: -1.3721, acc 0.9952, lambda 0.9999
# epoch 1904: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1905: train D loss: 0.6919, train F loss: -1.3704, acc 0.9944, lambda 0.9999
# epoch 1905: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1906: train D loss: 0.6933, train F loss: -1.3744, acc 0.9958, lambda 0.9999
# epoch 1906: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1907: train D loss: 0.6935, train F loss: -1.3758, acc 0.9954, lambda 0.9999
# epoch 1907: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1908: train D loss: 0.6938, train F loss: -1.3743, acc 0.9952, lambda 0.9999
# epoch 1908: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1909: train D loss: 0.6924, train F loss: -1.3705, acc 0.9950, lambda 0.9999
# epoch 1909: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1910: train D loss: 0.6931, train F loss: -1.3741, acc 0.9956, lambda 0.9999
# epoch 1910: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1911: train D loss: 0.6919, train F loss: -1.3705, acc 0.9962, lambda 0.9999
# epoch 1911: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1912: train D loss: 0.6921, train F loss: -1.3684, acc 0.9950, lambda 0.9999
# epoch 1912: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1913: train D loss: 0.6902, train F loss: -1.3700, acc 0.9958, lambda 0.9999
# epoch 1913: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1914: train D loss: 0.6905, train F loss: -1.3685, acc 0.9958, lambda 0.9999
# epoch 1914: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1915: train D loss: 0.6907, train F loss: -1.3700, acc 0.9958, lambda 0.9999
# epoch 1915: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1916: train D loss: 0.6901, train F loss: -1.3698, acc 0.9960, lambda 0.9999
# epoch 1916: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1917: train D loss: 0.6924, train F loss: -1.3735, acc 0.9948, lambda 0.9999
# epoch 1917: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1918: train D loss: 0.6924, train F loss: -1.3744, acc 0.9962, lambda 0.9999
# epoch 1918: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1919: train D loss: 0.6910, train F loss: -1.3724, acc 0.9968, lambda 0.9999
# epoch 1919: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1920: train D loss: 0.6905, train F loss: -1.3700, acc 0.9960, lambda 0.9999
# epoch 1920: lr_D:0.00009, lr_F:0.00048, lr_C:0.00002
# epoch 1921: train D loss: 0.6916, train F loss: -1.3727, acc 0.9958, lambda 0.9999
# epoch 1921: lr_D:0.00008, lr_F:0.00048, lr_C:0.00002
# epoch 1922: train D loss: 0.6920, train F loss: -1.3751, acc 0.9970, lambda 0.9999
# epoch 1922: lr_D:0.00008, lr_F:0.00048, lr_C:0.00002
# epoch 1923: train D loss: 0.6933, train F loss: -1.3718, acc 0.9950, lambda 0.9999
# epoch 1923: lr_D:0.00008, lr_F:0.00048, lr_C:0.00002
# epoch 1924: train D loss: 0.6942, train F loss: -1.3771, acc 0.9954, lambda 0.9999
# epoch 1924: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1925: train D loss: 0.6935, train F loss: -1.3764, acc 0.9960, lambda 0.9999
# epoch 1925: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1926: train D loss: 0.6933, train F loss: -1.3770, acc 0.9960, lambda 0.9999
# epoch 1926: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1927: train D loss: 0.6937, train F loss: -1.3774, acc 0.9970, lambda 0.9999
# epoch 1927: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1928: train D loss: 0.6936, train F loss: -1.3753, acc 0.9952, lambda 0.9999
# epoch 1928: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1929: train D loss: 0.6927, train F loss: -1.3752, acc 0.9956, lambda 0.9999
# epoch 1929: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1930: train D loss: 0.6928, train F loss: -1.3740, acc 0.9956, lambda 0.9999
# epoch 1930: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1931: train D loss: 0.6927, train F loss: -1.3728, acc 0.9958, lambda 0.9999
# epoch 1931: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1932: train D loss: 0.6927, train F loss: -1.3748, acc 0.9968, lambda 0.9999
# epoch 1932: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1933: train D loss: 0.6921, train F loss: -1.3728, acc 0.9958, lambda 0.9999
# epoch 1933: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1934: train D loss: 0.6923, train F loss: -1.3734, acc 0.9958, lambda 0.9999
# epoch 1934: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1935: train D loss: 0.6923, train F loss: -1.3739, acc 0.9966, lambda 0.9999
# epoch 1935: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1936: train D loss: 0.6942, train F loss: -1.3737, acc 0.9948, lambda 0.9999
# epoch 1936: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1937: train D loss: 0.6917, train F loss: -1.3735, acc 0.9958, lambda 0.9999
# epoch 1937: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1938: train D loss: 0.6933, train F loss: -1.3725, acc 0.9954, lambda 0.9999
# epoch 1938: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1939: train D loss: 0.6901, train F loss: -1.3714, acc 0.9966, lambda 0.9999
# epoch 1939: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1940: train D loss: 0.6922, train F loss: -1.3690, acc 0.9944, lambda 0.9999
# epoch 1940: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1941: train D loss: 0.6917, train F loss: -1.3709, acc 0.9952, lambda 0.9999
# epoch 1941: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1942: train D loss: 0.6914, train F loss: -1.3724, acc 0.9966, lambda 0.9999
# epoch 1942: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1943: train D loss: 0.6921, train F loss: -1.3737, acc 0.9960, lambda 0.9999
# epoch 1943: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1944: train D loss: 0.6915, train F loss: -1.3702, acc 0.9960, lambda 0.9999
# epoch 1944: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1945: train D loss: 0.6916, train F loss: -1.3743, acc 0.9964, lambda 0.9999
# epoch 1945: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1946: train D loss: 0.6919, train F loss: -1.3722, acc 0.9962, lambda 0.9999
# epoch 1946: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1947: train D loss: 0.6917, train F loss: -1.3733, acc 0.9964, lambda 0.9999
# epoch 1947: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1948: train D loss: 0.6919, train F loss: -1.3704, acc 0.9960, lambda 0.9999
# epoch 1948: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1949: train D loss: 0.6911, train F loss: -1.3721, acc 0.9966, lambda 0.9999
# epoch 1949: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1950: train D loss: 0.6916, train F loss: -1.3726, acc 0.9968, lambda 0.9999
# epoch 1950: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1951: train D loss: 0.6917, train F loss: -1.3730, acc 0.9962, lambda 0.9999
# epoch 1951: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1952: train D loss: 0.6914, train F loss: -1.3741, acc 0.9970, lambda 0.9999
# epoch 1952: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1953: train D loss: 0.6928, train F loss: -1.3739, acc 0.9956, lambda 0.9999
# epoch 1953: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1954: train D loss: 0.6921, train F loss: -1.3712, acc 0.9954, lambda 0.9999
# epoch 1954: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1955: train D loss: 0.6933, train F loss: -1.3762, acc 0.9964, lambda 0.9999
# epoch 1955: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1956: train D loss: 0.6932, train F loss: -1.3773, acc 0.9966, lambda 0.9999
# epoch 1956: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1957: train D loss: 0.6931, train F loss: -1.3752, acc 0.9962, lambda 0.9999
# epoch 1957: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1958: train D loss: 0.6932, train F loss: -1.3759, acc 0.9952, lambda 0.9999
# epoch 1958: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1959: train D loss: 0.6944, train F loss: -1.3789, acc 0.9962, lambda 0.9999
# epoch 1959: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1960: train D loss: 0.6936, train F loss: -1.3727, acc 0.9952, lambda 0.9999
# epoch 1960: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1961: train D loss: 0.6933, train F loss: -1.3734, acc 0.9960, lambda 0.9999
# epoch 1961: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1962: train D loss: 0.6925, train F loss: -1.3753, acc 0.9962, lambda 0.9999
# epoch 1962: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1963: train D loss: 0.6932, train F loss: -1.3753, acc 0.9958, lambda 0.9999
# epoch 1963: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1964: train D loss: 0.6929, train F loss: -1.3759, acc 0.9964, lambda 0.9999
# epoch 1964: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1965: train D loss: 0.6933, train F loss: -1.3729, acc 0.9950, lambda 0.9999
# epoch 1965: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1966: train D loss: 0.6930, train F loss: -1.3737, acc 0.9962, lambda 0.9999
# epoch 1966: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1967: train D loss: 0.6923, train F loss: -1.3736, acc 0.9962, lambda 0.9999
# epoch 1967: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1968: train D loss: 0.6919, train F loss: -1.3721, acc 0.9964, lambda 0.9999
# epoch 1968: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1969: train D loss: 0.6920, train F loss: -1.3696, acc 0.9956, lambda 0.9999
# epoch 1969: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1970: train D loss: 0.6925, train F loss: -1.3754, acc 0.9962, lambda 0.9999
# epoch 1970: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1971: train D loss: 0.6916, train F loss: -1.3722, acc 0.9964, lambda 0.9999
# epoch 1971: lr_D:0.00008, lr_F:0.00043, lr_C:0.00002
# epoch 1972: train D loss: 0.6927, train F loss: -1.3741, acc 0.9962, lambda 0.9999
# epoch 1972: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1973: train D loss: 0.6921, train F loss: -1.3738, acc 0.9966, lambda 0.9999
# epoch 1973: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1974: train D loss: 0.6920, train F loss: -1.3724, acc 0.9956, lambda 0.9999
# epoch 1974: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1975: train D loss: 0.6936, train F loss: -1.3744, acc 0.9960, lambda 0.9999
# epoch 1975: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1976: train D loss: 0.6920, train F loss: -1.3739, acc 0.9962, lambda 0.9999
# epoch 1976: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1977: train D loss: 0.6919, train F loss: -1.3700, acc 0.9946, lambda 0.9999
# epoch 1977: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1978: train D loss: 0.6935, train F loss: -1.3749, acc 0.9958, lambda 0.9999
# epoch 1978: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1979: train D loss: 0.6926, train F loss: -1.3742, acc 0.9956, lambda 0.9999
# epoch 1979: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1980: train D loss: 0.6922, train F loss: -1.3709, acc 0.9954, lambda 0.9999
# epoch 1980: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1981: train D loss: 0.6917, train F loss: -1.3735, acc 0.9962, lambda 0.9999
# epoch 1981: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1982: train D loss: 0.6925, train F loss: -1.3755, acc 0.9966, lambda 0.9999
# epoch 1982: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1983: train D loss: 0.6917, train F loss: -1.3738, acc 0.9968, lambda 0.9999
# epoch 1983: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1984: train D loss: 0.6923, train F loss: -1.3720, acc 0.9956, lambda 0.9999
# epoch 1984: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1985: train D loss: 0.6926, train F loss: -1.3743, acc 0.9964, lambda 0.9999
# epoch 1985: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1986: train D loss: 0.6934, train F loss: -1.3772, acc 0.9964, lambda 0.9999
# epoch 1986: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1987: train D loss: 0.6944, train F loss: -1.3793, acc 0.9962, lambda 0.9999
# epoch 1987: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1988: train D loss: 0.6936, train F loss: -1.3783, acc 0.9968, lambda 0.9999
# epoch 1988: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1989: train D loss: 0.6928, train F loss: -1.3769, acc 0.9966, lambda 0.9999
# epoch 1989: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1990: train D loss: 0.6920, train F loss: -1.3763, acc 0.9972, lambda 0.9999
# epoch 1990: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1991: train D loss: 0.6933, train F loss: -1.3783, acc 0.9972, lambda 0.9999
# epoch 1991: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1992: train D loss: 0.6927, train F loss: -1.3751, acc 0.9962, lambda 0.9999
# epoch 1992: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1993: train D loss: 0.6934, train F loss: -1.3775, acc 0.9966, lambda 0.9999
# epoch 1993: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1994: train D loss: 0.6935, train F loss: -1.3775, acc 0.9966, lambda 0.9999
# epoch 1994: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1995: train D loss: 0.6938, train F loss: -1.3746, acc 0.9954, lambda 0.9999
# epoch 1995: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1996: train D loss: 0.6939, train F loss: -1.3796, acc 0.9968, lambda 0.9999
# epoch 1996: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1997: train D loss: 0.6931, train F loss: -1.3739, acc 0.9950, lambda 0.9999
# epoch 1997: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1998: train D loss: 0.6934, train F loss: -1.3771, acc 0.9968, lambda 0.9999
# epoch 1998: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 1999: train D loss: 0.6924, train F loss: -1.3726, acc 0.9966, lambda 0.9999
# epoch 1999: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002
# epoch 2000: train D loss: 0.6931, train F loss: -1.3727, acc 0.9950, lambda 0.9999
# epoch 2000: lr_D:0.00007, lr_F:0.00043, lr_C:0.00002

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
with Progress(TextColumn("[progress.description]{task.description}"),
              BarColumn(),
              TextColumn("[progress.percentage]{task.percentage:>3.0f}%"),
              TimeRemainingColumn(),
              TimeElapsedColumn()) as progress:
    test_tqdm = progress.add_task(description="inference progress", total=len(test_dataloader))
    for i, (test_data, _) in (enumerate(test_dataloader)):
        test_data = test_data.cuda()

        class_logits = label_predictor(feature_extractor(test_data))

        x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
        result.append(x)
        progress.advance(test_tqdm)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %%
class Feature():
    def __init__(self):
        self.X = []
        self.TX = []
        self.labels = []

def get_features(model_list):
    features = []
    for model in model_list:
        model.cuda()
        features.append(Feature())

    for (x, y), (tx, _) in zip(source_dataloader, target_dataloader):
        x , tx= x.cuda(), tx.cuda()
        for i, model in enumerate(model_list):
            features[i].X.append(model(x).detach().cpu())
            features[i].TX.append(model(tx).detach().cpu())
            features[i].labels.append(y)
    
    for feature in features:
        feature.X = torch.cat(feature.X).numpy()
        feature.TX = torch.cat(feature.TX).numpy()
        feature.labels = torch.cat(feature.labels).numpy()
        
    return features

def visualization(features, marked_epoch):
    for i, feature in enumerate(features):
        X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(feature.X)
        TX_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(feature.TX)
        # Normalization the processed features 
        x_min, x_max = X_tsne.min(0), X_tsne.max(0)
        X_norm = (X_tsne - x_min) / (x_max - x_min)
        tx_min, tx_max = TX_tsne.min(0), TX_tsne.max(0)
        TX_norm = (TX_tsne - tx_min) / (tx_max - tx_min)
    
        plt.figure(figsize=(16, 8))
        plt.subplot(121)
        plt.title(f'epoch {marked_epoch[i]}:distribution of features accross different class')
        plt.scatter(X_norm[:, 0], X_norm[:, 1], c=feature.labels)
        plt.subplot(122)
        plt.title(f'epoch {marked_epoch[i]}:distribution of features accross different domain')
        plt.scatter(X_norm[:, 0], X_norm[:, 1], c='b', label='source domain')
        plt.scatter(TX_norm[:, 0], TX_norm[:, 1], c='r', label='target domain')
        plt.legend()
    plt.show()

# %%
model_list = []
for epoch in marked_epoch:
    model = FeatureExtractor()
    model.load_state_dict(torch.load(f'/kaggle/working/extractor_model_{epoch}.bin'))
    model_list.append(model)
    
visualization(get_features(model_list), marked_epoch)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.564s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 3.649230
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.034988
# [t-SNE] KL divergence after 1000 iterations: 1.830646
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.002s...
# [t-SNE] Computed neighbors for 5024 samples in 0.461s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 3.450809
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.788437
# [t-SNE] KL divergence after 1000 iterations: 1.721594
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.001s...
# [t-SNE] Computed neighbors for 5000 samples in 0.380s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.794210
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.907501
# [t-SNE] KL divergence after 1000 iterations: 1.776093
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.001s...
# [t-SNE] Computed neighbors for 5024 samples in 0.497s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.802202
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.578278
# [t-SNE] KL divergence after 1000 iterations: 1.730206
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.001s...
# [t-SNE] Computed neighbors for 5000 samples in 0.526s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.283271
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.121376
# [t-SNE] KL divergence after 1000 iterations: 1.724301
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.002s...
# [t-SNE] Computed neighbors for 5024 samples in 0.394s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.310465
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.230850
# [t-SNE] KL divergence after 1000 iterations: 1.615157
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.001s...
# [t-SNE] Computed neighbors for 5000 samples in 0.364s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.478951
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.189934
# [t-SNE] KL divergence after 1000 iterations: 1.791032
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.001s...
# [t-SNE] Computed neighbors for 5024 samples in 0.457s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.525269
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.208633
# [t-SNE] KL divergence after 1000 iterations: 1.557761
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.001s...
# [t-SNE] Computed neighbors for 5000 samples in 0.370s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.720141
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.955978
# [t-SNE] KL divergence after 1000 iterations: 1.852883
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.001s...
# [t-SNE] Computed neighbors for 5024 samples in 0.378s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 1.758660
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.736084
# [t-SNE] KL divergence after 1000 iterations: 1.578323
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.001s...
# [t-SNE] Computed neighbors for 5000 samples in 0.452s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.034690
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.801498
# [t-SNE] KL divergence after 1000 iterations: 1.944015
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5024 samples in 0.001s...
# [t-SNE] Computed neighbors for 5024 samples in 0.372s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5024
# [t-SNE] Computed conditional probabilities for sample 2000 / 5024
# [t-SNE] Computed conditional probabilities for sample 3000 / 5024
# [t-SNE] Computed conditional probabilities for sample 4000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5000 / 5024
# [t-SNE] Computed conditional probabilities for sample 5024 / 5024
# [t-SNE] Mean sigma: 2.151448
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.484726
# [t-SNE] KL divergence after 1000 iterations: 1.560929

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
# Hints:
# Set features_extractor to eval mode
# Load saved checkpoints
# Start evaluation and collect features and labels

# %% [markdown]
# ## Step2: Apply t-SNE and normalize

# %%
# process extracted features with t-SNE
# X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

# Normalization the processed features 
# x_min, x_max = X_tsne.min(0), X_tsne.max(0)
# X_norm = (X_tsne - x_min) / (x_max - x_min)

# %% [markdown]
# ## Step3: Visualization with matplotlib

# %%
# Data Visualization
# Use matplotlib to plot the distribution
# The shape of X_norm is (N,2)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08902047@ntu.edu.tw / mlta-2023-spring@googlegroups.com。
